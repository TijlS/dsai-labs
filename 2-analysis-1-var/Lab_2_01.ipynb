# %% [markdown]
# # Lab 2.01 - Univariate Analysis

# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %% [markdown]
# ## Exercise 1 - metro
# At a metro station, a regular passenger records how long (in seconds) he has to wait for a train to arrive once he gets to the platform.
# Find the median and the interquartile range of these times.
#
# Help: https://numpy.org/devdocs/reference/generated/numpy.quantile.html
#
# **Solutions**
# Median: 49.5
# Inter Quartile Range: 54.5
#
# Source: Complete Probability & Statistics 1 for Cambridge International As & A Level

# %%
a = np.array([87, 42, 0, 62, 124, 0, 58, 37, 74, 94, 182, 23, 17, 62, 29, 17, 82, 54, 0, 45])

print(f'Median: {np.median(a)}')
print(f'Inter Quartile Range: {stats.iqr(a)}')
# Of np.quartile(a, 0.75) - np.quartile(a, 0.25)
# Out:
# Median: 49.5
# Inter Quartile Range: 54.5

# %% [markdown]
# # Exercise 2
# The length of time, in minutes, that customers spend in a coffee shop is recorded. Calculate the following statistics:
#
# * Median
# * Range
# * Quartiles
# * Interquartile range
#
# Source: Complete Probability & Statistics 1 for Cambridge International As & A Level

# %%
times = np.array([17, 15, 9, 31, 33, 41, 8, 14, 13, 22, 27, 43, 32, 14])

print(f'Median: {np.median(times)}')
print(f'Range: {times.max() - times.min()}')
print('Quartiles:')
print(np.quantile(times, 0.25))
print(np.quantile(times, 0.5))
print(np.quantile(times, 0.75))
print(f'Inter Quartile Range: {np.quantile(times, 0.75) - np.quantile(times, 0.25)}')
# Out:
# Median: 19.5
# Range: 35
# Quartiles:
# 14.0
# 19.5
# 31.75
# Inter Quartile Range: 17.75
